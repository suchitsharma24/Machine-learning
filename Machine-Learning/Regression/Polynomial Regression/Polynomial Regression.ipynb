# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importing dataset
df = pd.read_csv("data/Position_Salaries.csv")
X = df.iloc[:,1:2].values
y = df.iloc[:,2].values

# %%
#as we have only 10 observation in the dataset, we will train our model with al the data. Hence, no split required

# %%
#Fit linear regression to the dataset (for comparison with polynomial regression model)
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Fit Polynomial regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Visualoze the Linear Regression results
plt.scatter(X,y, color='red')
plt.plot(X,lin_reg.predict(X))
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Posiiton Level')
plt.ylabel('Salary')
plt.show()

# %%
#Visualoze the Polynolial Regression results
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y, color='red')
plt.plot(X,lin_reg_2.predict(poly_reg.fit_transform(X)))
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Posiiton Level')
plt.ylabel('Salary')
plt.show()

# %%
#Predict the salary of ex-employee with Linear Regression
lin_reg.predict(6.5)
# Out:
# array([ 330378.78787879])

# %%
#Predict the salary of ex-employee with Polynomial Regression
lin_reg_2.predict(poly_reg.fit_transform(6.5))
# Out:
# array([ 158862.45265153])

# %%
#Preiction with Polynomial Regression did accurate preiction as compared to Linear Regression model
#Employee is not lying as per the above polynomial regression result.
